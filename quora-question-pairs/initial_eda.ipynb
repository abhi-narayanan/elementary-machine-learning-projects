# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("questions.csv")

# %%
df.shape
# Out:
# (404351, 6)

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 229187  229187  451648  451649
# 369716  369716  723518  723519
# 314190  314190  616622  616623
# 368583  368583  721343  721344
# 15275    15275   30491   30492
# 14306    14306   28559   28560
# 140539  140539  278192  278193
# 206785  206785   91737  407947
# 43661    43661   86951   86952
# 167780  167780  331589  331590
#
#                                                 question1  \
# 229187  How does the rules for 7-a-side football (foot...
# 369716       Could an Inuit survive on a tropical island?
# 314190              What is your favourite quote and why?
# 368583             What are the games to play in parties?
# 15275   What is best way to crack the Civil Services E...
# 14306   What are some examples of positive and negativ...
# 140539  Is Google stock a good and safe investment for...
# 206785          How easy is to decompile a Qt executable?
# 43661             How can you become addicted to studies?
# 167780   What are the best books for SSC CGL preparation?
#
#                                                 question2  is_duplicate
# 229187  What would football be if there were no off-si...             0
# 369716          Which islands are all coral reef islands?             0
# 314190     What are some of your favorite quotes and why?             1
# 368583                  What are games in fairwell party?             0
# 15275   What will be the best optional paper for civil...             0
# 14306   What are examples of positive and negative fee...             1
# 140539  I have 50,000 usd and my bank's yearly savings...             0
# 206785                         What is the Qt(framework)?             0
# 43661                   How do I get addicted to studies?             1
# 167780  Which is the best English book to prepare for ...             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404351 entries, 0 to 404350
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404351 non-null  int64
#  1   qid1          404351 non-null  int64
#  2   qid2          404351 non-null  int64
#  3   question1     404350 non-null  object
#  4   question2     404349 non-null  object
#  5   is_duplicate  404351 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
# missing values
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# Duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
# Data distribution
print(df['is_duplicate'].value_counts())
print(df['is_duplicate'].value_counts()/len(df)*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# 0    255045
# 1    149306
# Name: is_duplicate, dtype: int64
# 0    63.07515
# 1    36.92485
# Name: is_duplicate, dtype: float64
# <Axes: >

# %%
# Repeated questions
qid = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
print("Number of unique questions =", np.unique(qid).shape[0])
x = qid.value_counts()>1
print("Number of repeated questions =", x[x].shape[0])
# Out:
# Number of unique questions = 789801
# Number of repeated questions = 13698

# %%
# Repeated questions histogram
plt.hist(qid.value_counts().values, bins=160)
plt.yscale('log')
plt.show()
